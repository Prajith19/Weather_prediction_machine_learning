# %%
import pandas as pd

weather = pd.read_csv("D:/weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2022-12-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  20.13
# 2022-12-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  12.75
# 2022-12-27  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  10.74
# 2022-12-28  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   8.50
# 2022-12-29  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT11  WT13  WT14  WT15  WT16  \
# DATE                                      ...
# 1970-01-01   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   NaN   1.0
# 1970-01-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 2022-12-25   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-12-26   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-12-27   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-12-28   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-12-29   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
#
#             WT17  WT18  WT21  WT22  WV01
# DATE
# 1970-01-01   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   1.0   NaN   NaN   NaN
# 1970-01-04   NaN   1.0   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...
# 2022-12-25   NaN   NaN   NaN   NaN   NaN
# 2022-12-26   NaN   NaN   NaN   NaN   NaN
# 2022-12-27   NaN   NaN   NaN   NaN   NaN
# 2022-12-28   NaN   NaN   NaN   NaN   NaN
# 2022-12-29   NaN   NaN   NaN   NaN   NaN
#
# [19356 rows x 44 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.503255
# ACSH       0.503203
# AWND       0.264311
# FMTM       0.476958
# PGTM       0.366243
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000052
# TAVG       0.677981
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998398
# WDF1       0.503461
# WDF2       0.496900
# WDF5       0.501188
# WDFG       0.735431
# WDFM       0.999948
# WESD       0.686350
# WSF1       0.503306
# WSF2       0.496900
# WSF5       0.501240
# WSFG       0.614435
# WSFM       0.999948
# WT01       0.630296
# WT02       0.935059
# WT03       0.933509
# WT04       0.982589
# WT05       0.981194
# WT06       0.990649
# WT07       0.994420
# WT08       0.797427
# WT09       0.992767
# WT11       0.999277
# WT13       0.887115
# WT14       0.954174
# WT15       0.997830
# WT16       0.660209
# WT17       0.996900
# WT18       0.939709
# WT21       0.999742
# WT22       0.997468
# WV01       0.999948
# dtype: float64

# %%
 valid_columns = weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather =  weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-12-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-27  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-28  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-29  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21
# ...          ...   ...
# 2022-12-25    28    14
# 2022-12-26    29    18
# 2022-12-27    35    28
# 2022-12-28    45    27
# 2022-12-29    46    32
#
# [19356 rows x 7 columns]

# %%
weather =  weather.ffill()
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-12-20', '2022-12-21', '2022-12-22', '2022-12-23', '2022-12-24',
#        '2022-12-25', '2022-12-26', '2022-12-27', '2022-12-28', '2022-12-29'],
#       dtype='object', name='DATE', length=19356)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2022-12-20', '2022-12-21', '2022-12-22', '2022-12-23',
#                '2022-12-24', '2022-12-25', '2022-12-26', '2022-12-27',
#                '2022-12-28', '2022-12-29'],
#               dtype='datetime64[ns]', name='DATE', length=19356, freq=None)

# %%
weather.index.year
# Out:
# Int64Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#             ...
#             2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022],
#            dtype='int64', name='DATE', length=19356)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    363
# Name: DATE, dtype: int64

# %%
 weather["tmax"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
weather["tmin"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
weather["snwd"].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-12-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-27  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-28  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-29  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-12-25    28    14    29.0
# 2022-12-26    29    18    35.0
# 2022-12-27    35    28    45.0
# 2022-12-28    45    27    46.0
# 2022-12-29    46    32     NaN
#
# [19356 rows x 8 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-12-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-27  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-28  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-12-29  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-12-25    28    14    29.0
# 2022-12-26    29    18    35.0
# 2022-12-27    35    28    45.0
# 2022-12-28    45    27    46.0
# 2022-12-29    46    32    46.0
#
# [19356 rows x 8 columns]

# %%
weather.corr()
# Out:
#             prcp      snow      snwd      tmax      tmin    target
# prcp    1.000000  0.151015  0.001237 -0.006884  0.052468 -0.003136
# snow    0.151015  1.000000  0.232614 -0.174633 -0.158840 -0.172289
# snwd    0.001237  0.232614  1.000000 -0.259187 -0.256270 -0.240396
# tmax   -0.006884 -0.174633 -0.259187  1.000000  0.955358  0.915125
# tmin    0.052468 -0.158840 -0.256270  0.955358  1.000000  0.915376
# target -0.003136 -0.172289 -0.240396  0.915125  0.915376  1.000000

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        
        combined = pd.concat([test["target"], preds], axis=1)
        
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2022-12-25    29.0   29.504774   0.504774
# 2022-12-26    35.0   32.020275   2.979725
# 2022-12-27    45.0   39.876059   5.123941
# 2022-12-28    46.0   43.836350   2.163650
# 2022-12-29    46.0   46.868795   0.868795
#
# [15706 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 5.141314457606592

# %%
 predictions["diff"].mean()
# Out:
# 5.141314457606569

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2007-03-26    78.0   49.744725  28.255275
# 1999-01-02    53.0   25.911898  27.088102
# 1998-03-26    80.0   53.033957  26.966043
# 1985-04-18    84.0   57.071179  26.928821
# 1990-03-12    85.0   58.144310  26.855690
# ...            ...         ...        ...
# 2006-08-20    88.0   88.002937   0.002937
# 2019-03-01    40.0   40.002460   0.002460
# 1992-06-11    76.0   76.001641   0.001641
# 2011-09-16    66.0   66.000831   0.000831
# 2014-03-25    39.0   38.999920   0.000080
#
# [15706 rows x 3 columns]

# %%
pd.Series(rr.coef_, index=predictors)
# Out:
# prcp   -1.234541
# snow   -0.408181
# snwd    0.053086
# tmax    0.447724
# tmin    0.516944
# dtype: float64

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
    
rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)
        
weather = weather.iloc[14:,:]
weather = weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)
    weather

# %%
weather = weather.iloc[14:,:]
weather = weather.fillna(0)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictions = backtest(weather, rr, predictors)
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 4.7907791628372

# %%
predictions
# Out:
#             actual  prediction      diff
# DATE
# 1980-01-27    37.0   38.114097  1.114097
# 1980-01-28    31.0   39.557075  8.557075
# 1980-01-29    28.0   35.908778  7.908778
# 1980-01-30    26.0   31.503658  5.503658
# 1980-01-31    24.0   29.800728  5.800728
# ...            ...         ...       ...
# 2022-12-25    29.0   33.288585  4.288585
# 2022-12-26    35.0   37.224046  2.224046
# 2022-12-27    45.0   41.903967  3.096033
# 2022-12-28    46.0   44.595027  1.404973
# 2022-12-29    46.0   45.799084  0.200916
#
# [15678 rows x 3 columns]

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 37.55506711830574

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.381195  30.618805
# 2007-03-26    78.0   49.963324  28.036676
# 1998-03-26    80.0   51.969821  28.030179
# 2003-04-15    86.0   59.409931  26.590069
# 1985-04-18    84.0   58.384101  25.615899
# ...            ...         ...        ...
# 2002-09-24    74.0   74.003321   0.003321
# 2022-11-05    70.0   70.002880   0.002880
# 1980-03-20    49.0   48.998018   0.001982
# 2016-06-29    85.0   85.001276   0.001276
# 2012-02-14    46.0   46.000142   0.000142
#
# [15678 rows x 3 columns]

# %%
weather.loc["1990-03-07": "1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  ...  \
# DATE                                                                ...
# 1990-03-07    32    14    39.0       33.666667           -0.049505  ...
# 1990-03-08    39    20    43.0       35.000000            0.114286  ...
# 1990-03-09    43    29    47.0       38.000000            0.131579  ...
# 1990-03-10    47    39    59.0       43.000000            0.093023  ...
# 1990-03-11    59    41    59.0       49.666667            0.187919  ...
# 1990-03-12    59    43    85.0       55.000000            0.072727  ...
# 1990-03-13    85    41    62.0       67.666667            0.256158  ...
# 1990-03-14    62    46    55.0       68.666667           -0.097087  ...
# 1990-03-15    55    43    62.0       67.333333           -0.183168  ...
# 1990-03-16    62    48    61.0       59.666667            0.039106  ...
# 1990-03-17    61    49    59.0       59.333333            0.028090  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1990-03-07        25.000000            -0.440000         0.047857
# 1990-03-08        24.071429            -0.169139         0.040714
# 1990-03-09        22.785714             0.272727         0.031429
# 1990-03-10        23.428571             0.664634         0.020714
# 1990-03-11        25.500000             0.607843         0.021429
# 1990-03-12        27.928571             0.539642         0.021429
# 1990-03-13        29.500000             0.389831         0.020000
# 1990-03-14        30.857143             0.490741         0.020000
# 1990-03-15        32.214286             0.334812         0.020000
# 1990-03-16        33.428571             0.435897         0.020000
# 1990-03-17        34.357143             0.426195         0.038571
#
#             rolling_14_prcp_pct  month_avg_tmax  day_avg_tmax  month_avg_tmin  \
# DATE
# 1990-03-07            -1.000000       48.590112     45.428571       34.567783
# 1990-03-08            -1.000000       48.574841     46.571429       34.544586
# 1990-03-09            -0.681818       48.565978     45.619048       34.535771
# 1990-03-10            -0.517241       48.563492     43.809524       34.542857
# 1990-03-11             1.333333       48.580032     46.142857       34.553090
# 1990-03-12            -1.000000       48.596519     48.142857       34.566456
# 1990-03-13            -1.000000       48.654028     48.761905       34.576619
# 1990-03-14            -1.000000       48.675079     50.190476       34.594637
# 1990-03-15            -1.000000       48.685039     49.714286       34.607874
# 1990-03-16            -1.000000       48.705975     50.095238       34.628931
# 1990-03-17             5.740741       48.725275     48.095238       34.651491
#
#             day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 1990-03-07     31.857143        0.119410      0.111429
# 1990-03-08     31.190476        0.119220      0.076667
# 1990-03-09     30.952381        0.119046      0.036190
# 1990-03-10     31.761905        0.118873      0.071905
# 1990-03-11     31.904762        0.118764      0.126667
# 1990-03-12     34.285714        0.118576      0.167619
# 1990-03-13     34.285714        0.118389      0.091429
# 1990-03-14     36.809524        0.118202      0.259524
# 1990-03-15     35.761905        0.118016      0.066667
# 1990-03-16     35.619048        0.117830      0.083810
# 1990-03-17     34.619048        0.118053      0.079048
#
# [11 rows x 26 columns]

# %%
(predictions["diff"].round().value_counts().sort_index() / predictions.shape[0]).plot()
predictions
# Out:
#             actual  prediction      diff
# DATE
# 1980-01-27    37.0   38.114097  1.114097
# 1980-01-28    31.0   39.557075  8.557075
# 1980-01-29    28.0   35.908778  7.908778
# 1980-01-30    26.0   31.503658  5.503658
# 1980-01-31    24.0   29.800728  5.800728
# ...            ...         ...       ...
# 2022-12-25    29.0   33.288585  4.288585
# 2022-12-26    35.0   37.224046  2.224046
# 2022-12-27    45.0   41.903967  3.096033
# 2022-12-28    46.0   44.595027  1.404973
# 2022-12-29    46.0   45.799084  0.200916
#
# [15678 rows x 3 columns]

# %%
predictions
# Out:
#             actual  prediction      diff
# DATE
# 1980-01-27    37.0   38.114097  1.114097
# 1980-01-28    31.0   39.557075  8.557075
# 1980-01-29    28.0   35.908778  7.908778
# 1980-01-30    26.0   31.503658  5.503658
# 1980-01-31    24.0   29.800728  5.800728
# ...            ...         ...       ...
# 2022-12-25    29.0   33.288585  4.288585
# 2022-12-26    35.0   37.224046  2.224046
# 2022-12-27    45.0   41.903967  3.096033
# 2022-12-28    46.0   44.595027  1.404973
# 2022-12-29    46.0   45.799084  0.200916
#
# [15678 rows x 3 columns]

# %%
predictions
# Out:
#             actual  prediction      diff
# DATE
# 1980-01-27    37.0   38.114097  1.114097
# 1980-01-28    31.0   39.557075  8.557075
# 1980-01-29    28.0   35.908778  7.908778
# 1980-01-30    26.0   31.503658  5.503658
# 1980-01-31    24.0   29.800728  5.800728
# ...            ...         ...       ...
# 2022-12-25    29.0   33.288585  4.288585
# 2022-12-26    35.0   37.224046  2.224046
# 2022-12-27    45.0   41.903967  3.096033
# 2022-12-28    46.0   44.595027  1.404973
# 2022-12-29    46.0   45.799084  0.200916
#
# [15678 rows x 3 columns]

# %%
predictions
# Out:
#             actual  prediction      diff
# DATE
# 1980-01-27    37.0   38.114097  1.114097
# 1980-01-28    31.0   39.557075  8.557075
# 1980-01-29    28.0   35.908778  7.908778
# 1980-01-30    26.0   31.503658  5.503658
# 1980-01-31    24.0   29.800728  5.800728
# ...            ...         ...       ...
# 2022-12-25    29.0   33.288585  4.288585
# 2022-12-26    35.0   37.224046  2.224046
# 2022-12-27    45.0   41.903967  3.096033
# 2022-12-28    46.0   44.595027  1.404973
# 2022-12-29    46.0   45.799084  0.200916
#
# [15678 rows x 3 columns]
